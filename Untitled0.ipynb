# %% [markdown]
# <a href="https://colab.research.google.com/github/hacosta09/singlylink/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#include <iostream>

struct Node {
    int data;
    Node* next;

    Node(int data) : data(data), next(nullptr) {}
};

class SinglyLinkedList {
private:
    Node* head;

public:
    SinglyLinkedList() : head(nullptr) {}

    ~SinglyLinkedList() {
        while (head != nullptr) {
            Node* temp = head;
            head = head->next;
            delete temp;
        }
    }

    // Insert data at a specific index
    void insert(int data, int index) {
        if (index < 0) {
            std::cerr << "Index out of bounds" << std::endl;
            return;
        }

        Node* newNode = new Node(data);

        if (index == 0) {
            newNode->next = head;
            head = newNode;
            return;
        }

        Node* current = head;
        for (int i = 0; i < index - 1 && current != nullptr; ++i) {
            current = current->next;
        }

        if (current == nullptr) {
            std::cerr << "Index out of bounds" << std::endl;
            delete newNode;
            return;
        }

        newNode->next = current->next;
        current->next = newNode;
    }

    // Delete node at a specific index
    void remove(int index) {
        if (index < 0 || head == nullptr) {
            std::cerr << "Index out of bounds or empty list" << std::endl;
            return;
        }

        if (index == 0) {
            Node* temp = head;
            head = head->next;
            delete temp;
            return;
        }

        Node* current = head;
        for (int i = 0; i < index - 1 && current != nullptr; ++i) {
            current = current->next;
        }

        if (current == nullptr || current->next == nullptr) {
            std::cerr << "Index out of bounds" << std::endl;
            return;
        }

        Node* temp = current->next;
        current->next = temp->next;
        delete temp;
    }

    // Print the list
    void printList() const {
        Node* current = head;
        while (current != nullptr) {
            std::cout << current->data << " -> ";
            current = current->next;
        }
        std::cout << "nullptr" << std::endl;
    }
};

int main() {
    SinglyLinkedList list;
    list.insert(10, 0);
    list.insert(20, 1);
    list.insert(30, 2);
    list.printList();

    list.remove(1);
    list.printList();

    return 0;
}
